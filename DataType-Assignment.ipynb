# %%
'''1. Write a program to add two lists index-wise. Create a new list that contains the 0th index item from both the list,
then the 1st index item, and so on till the last element. any leftover items will get added at the end of the new list.'''

#Given List:
list1 = ["M", "na", "i", "Ra"]
list2 = ["y", "me", "s", "hul"]

list3 = []

#for i in range(len(list1)):
#  list3.append([list1[i] + ',' + list2[i]])

zip_list = zip(list1,list2)

print(list(zip_list))
# Out:
# [('M', 'y'), ('na', 'me'), ('i', 's'), ('Ra', 'hul')]

# %%
'''''2. Write a program to add item 7000 after 6000 in the following Python List

	list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]'''

list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]

list1[2][2].append(7000)

print(list1)
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %%
'''3. Suppose you are given a list of candy and another list of same size representing no of items of respective candy.

	i.e -

	candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
	no_of_items = [10,20,34,74,32]
	Write a program to show no. of items of each candy type.'''

candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
no_of_items = [10,20,34,74,32]

for i in range(len(candy_list)):
  print(candy_list[i] + "-" + str(no_of_items[i]))
# Out:
# Jelly Belly-10
# Kit Kat-20
# Double Bubble-34
# Milky Way-74
# Three Musketeers-32

# %%
#4. Running Sum on list Write a program to print a list after performing running sum on it.

list1 = [1,2,3,4,5,6]
added_list = []

a = 0

for i in list1:
  a = i + a
  added_list.append(a)

print(added_list)
# Out:
# [1, 3, 6, 10, 15, 21]

# %%
"""5. You are given a list of integers. You are asked to make a list by running through elements of the list by adding all elements greater and itself.

	i.e. Say given list is [2,4,6,10,1] resultant list will be [22,20,10,23].

	For 1st element 2 ->> these are greater (4+6+10) values and 2 itself so on adding becomes 22.

	For 2nd element 4 ->> greater elements are (6, 10) and 4 itself, so on adding 20

	like wise for all other elememts."""

l = [2,4,6,10,1]   #E-->[22,20,16,10,23]
newlist = []

a = 0
for i in l:
  for j in l:
    if j >= i:
      a = a + j
  newlist.append(a)
  a = 0

print(newlist)
# Out:
# [22, 20, 16, 10, 23]

# %%
#6. Find list of common unique items from two list. and show in increasing order

num1 = [23,45,67,78,89,34]
num2 = [34,89,55,56,39,67]
#output [34, 67, 89]

new = []

for i in num1:
  if i in num2:
    new.append(i)

new.sort()
print(new)
# Out:
# [34, 67, 89]

# %%
'''7. Sort a list of alphanumeric strings based on product value of numeric character in it. If in any string there is no numeric character take it's product value as 1.

	Input:

	['1ac21', '23fg', '456', '098d','1','kls']
	Output:

	['456', '23fg', '1ac21', '1', 'kls', '098d']'''

alphanumeric_list = ['1ac21', '23fg', '456', '098d','1','kls']

def product_value(string):
    product = 1
    for i in string:
        if i.isdigit():
            product = product * int(i)
    return product

alphanumeric_list.sort(key = product_value, reverse = True)
print(alphanumeric_list)
# Out:
# ['456', '23fg', '1ac21', '1', 'kls', '098d']

# %%
'''8. Write a program that can find the max number of each row of a matrix
	Example:

	Input:

	[[1,2,3],[4,5,6],[7,8,9]]
	Output:
  [3,6,9]'''

l =	[[1,2,3],[4,5,6],[7,8,9]]
new = []
for i in l:
  new.append(max(i))
print(new)
# Out:
# [3, 6, 9]

# %%
'''9. Shortlist Students for a Job role Ask user to input students record and store in tuples for each record. Then Ask user to input three things he wants in the
   candidate- Primary Skill, Higher Education, Year of Graduation.

	Show every students record in form of tuples if matches all required criteria.

	It is assumed that there will be only one primry skill.

	If no such candidate found, print No such candidate

	Input:

	Enter No of records- 2
	Enter Details of student-1
	Enter Student name- Manohar
	Enter Higher Education- B.Tech
	Enter Primary Skill- Python
	Enter Year of Graduation- 2022
	Enter Details of student-2
	Enter Student name- Ponian
	Enter Higher Education- B.Sc.
	Enter Primary Skill- C++
	Enter Year of Graduation- 2020

	Enter Job Role Requirement
	Enter Skill- Python
	Enter Higher Education- B.Tech
	Enter Year of Graduation- 2022
	Output

	('Manohar', 'B.tech', 'Python', '2022')'''


n = int(input("Enter No of records: "))

students = []

for i in range(n):
    print(f"Enter Details of student-{i+1}")

    name = input("Enter Student name: ")
    edu = input("Enter Higher Education: ")
    skill = input("Enter Primary Skill: ")
    year = input("Enter Year of Graduation: ")

    students.append((name, edu, skill, year))


print("\nEnter Job Role Requirement")
req_skill = input("Enter Skill: ")
req_edu = input("Enter Higher Education: ")
req_year = input("Enter Year of Graduation: ")

found = False

for student in students:
    if (student[1].lower() == req_edu.lower() and
        student[2].lower() == req_skill.lower() and
        student[3] == req_year):

        print(student)
        found = True

if not found:
    print("No such candidate")
# Out:
# Enter No of records: 1
# Enter Details of student-1
# Enter Student name: yash
# Enter Higher Education: be
# Enter Primary Skill: python
# Enter Year of Graduation: 2025
#
# Enter Job Role Requirement
# Enter Skill: python
# Enter Higher Education: be
# Enter Year of Graduation: 2025
# ('yash', 'be', 'python', '2025')

# %%
'''10. Write a program to find set of common elements in three lists using sets.

	Input : ar1 = [1, 5, 10, 20, 40, 80]
			ar2 = [6, 7, 20, 80, 100]
			ar3 = [3, 4, 15, 20, 30, 70, 80, 120]

	Output : [80, 20]'''

ar1 = [1, 5, 10, 20, 40, 80]
ar2 = [6, 7, 20, 80, 100]
ar3 = [3, 4, 15, 20, 30, 70, 80, 120]

set1 = set(ar1)  #Use set intersection (&)
set2 = set(ar2)
set3 = set(ar3)

common = set1 & set2 & set3
result = list(common)
print(result)
#2 method
set.intersection(set1,set2,set3)
# Out:
# [80, 20]
# {20, 80}

# %%
'''11. Write a program to count unique number of vowels using sets in a given string. Lowercase and upercase vowels will be taken as different.

	Input:

	Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"
	Output:

	No of unique vowels-6'''

Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"

vowels = set("aeiouAEIOU")
found_vowels = set()

for i in Str1:
  if i in vowels:
    found_vowels.add(i)

print("No of unique vowels -",len(found_vowels))
# Out:
# No of unique vowels - 6

# %%
'''12. Intersection of two lists. Intersection of two list means we need to take all those elements which are common to both
 of the initial lists and store them into another list. Only use using list-comprehension.
	Example 1:

	Input:

	lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}
	lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}
	Output:

	[9, 10, 4, 5]
	Example 2:

	Input:

	lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
	lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}
	Output:

	[9, 11, 26, 28]'''

lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}
lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}

result = [i for i in lst1 if i in lst2]
print(result)

lst3 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
lst4 = {9, 9, 74, 21, 45, 11, 63, 28, 26}

result = [i for i in lst3 if i in lst4]
print(result)
# Out:
# [4, 5, 9, 10]
# [9, 11, 26, 28]

# %%
'''13. Convert a list of Tuples into Dictionary.
	Example 1:

	Input:

	[("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]
	Output:

	{'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}
	Example 2:

	Input:

	[('A', 1), ('B', 2), ('C', 3)]
	Output:

	{'A': [1], 'B': [2], 'C': [3]}'''

l = [("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]

result = {}

for name,value in l:
  result[name] = [value]

print(result)


l1 = [('A', 1), ('B', 2), ('C', 3)]

result ={}
for char,no in l1:
  result [char] = [no]
print(result)
# Out:
# {'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}
# {'A': [1], 'B': [2], 'C': [3]}

# %%
'''14. Write a Python function that takes a list and returns a new list with unique elements of the first list.
	Exercise 1:

	Input:

	[1,2,3,3,3,3,4,5]
	Output:

	[1, 2, 3, 4, 5]'''

list = [1,2,3,3,3,3,4,5]

def unique_list(list):
  result = []

  for i in list:
    if i not in result:
      result.append(i)
  return result
print(unique_list(list))
# Out:
# [1, 2, 3, 4, 5]

# %%
'''15.  Write a Python program to print the even numbers from a given list.
		Sample List : [1, 2, 3, 4, 5, 6, 7, 8, 9]
		Expected Result : [2, 4, 6, 8]'''

List = [1, 2, 3, 4, 5, 6, 7, 8, 9]

lr = []

for i in List:
  if i % 2 == 0:
    lr.append(i)
print(lr)
# Out:
# [2, 4, 6, 8]

# %%
'''16. Write a Python function to check whether a number is perfect or not.¶
	A Perfect number is a number that is half the sum of all of its positive divisors (including itself).

	Example :

	The first perfect number is 6, because 1, 2, and 3 are its proper positive divisors, and 1 + 2 + 3 = 6.
	Equivalently, the number 6 is equal to half the sum of all its positive divisors: ( 1 + 2 + 3 + 6 ) / 2 = 6.

	The next perfect number is 28 = 1 + 2 + 4 + 7 + 14. This is followed by the perfect numbers 496 and 8128.'''

def is_perfect(n):
    sum_div = 0

    for i in range(1, n):
        if n % i == 0:
            sum_div += i

    if sum_div == n:
        return True
    else:
        return False


# Example usage
num = int(input("Enter a number: "))

if is_perfect(num):
    print("Perfect Number")
else:
    print("Not a Perfect Number")
# Out:
# Enter a number: 496
# Perfect Number

# %%
'''17. Write a Python function to concatenate any no of dictionaries to create a new one.
	Sample Dictionary :
	dic1={1:10, 2:20}
	dic2={3:30, 4:40}
	dic3={5:50,6:60}
	Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}'''

dic1={1:10, 2:20}
dic2={3:30, 4:40}
dic3={5:50, 6:60}

def big_dict(*dict):
	result = {}
	for i in dict:
		result.update(i)
	return result

print(big_dict(dic1,dic2,dic3))

'''result = {}

result.update(dic1)
result.update(dic2)
result.update(dic3)

print(result)'''
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
# 'result = {}\n\nresult.update(dic1)\nresult.update(dic2)\nresult.update(dic3)\n\nprint(result)'

# %%
'''18. Write a python function that receives a list of integers and prints out a histogram of bin size 10

	Input:
	[13,42,15,37,22,39,41,50]
	Output:
	{11-20:2,21-30:1,31-40:2,41-50:3}'''

def histogram(lst):
    result = {}

    for num in lst:
        start = (num // 10) * 10 + 1
        end = start + 9

        key = f"{start}-{end}"

        result[key] = result.get(key, 0) + 1

    print(result)


# Test
histogram([13,42,15,37,22,39,41,50])
# Out:
# {'11-20': 2, '41-50': 2, '31-40': 2, '21-30': 1, '51-60': 1}

# %%
data = [1, 2, 3, 4, 5, 6, 2, 8, 9, 10, 6]
li = []
for i in data:
  if i % 2 == 0:
    li.append(i)
sl = set(li)
ll = sorted(sl,reverse=True)

print(ll)
a = 0    #add all the list
for i in ll:
  a = i + a

print(a)
# Out:
# [10, 8, 6, 4, 2]
# 30
