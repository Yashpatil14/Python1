# %%
'''1. Write a Python program to create a class representing a Circle. Include methods to calculate its area and perimeter.'''

import math

class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.radius


c1 = Circle(5)

print("Area:", c1.area())
print("Perimeter:", c1.perimeter())
# Out:
# Area: 78.53981633974483
# Perimeter: 31.41592653589793

# %%
'''2. Write a Python program to create a person class. Include attributes like name, country and date of birth. Implement a method to determine the person's age.'''


class person:
    def __init__(self,name,country,date_of_birth):
        self.name = name
        self.country = country
        self.date_of_birth = date_of_birth

    def age(self):
        today = date.today()
        age = today.year - self.date_of_birth.year
        return age

p1 = person("Yash", "India", date(2003, 6, 14))

print(p1.name)
print(p1.country)
print(p1.age())
# Out:
# Yash
# India
# 23

# %%
'''3. Write a Python program to create a calculator class. Include methods for basic arithmetic operations.'''

class calculate:
  def __init__(self,v1,v2):
    self.v1 = v1
    self.v2 = v2

  def add(self):
    return self.v1 + self.v2

  def sub(self):
    return self.v1 - self.v2

  def mul(self):
    return self.v1 * self.v2

  def div(self):
    if self.v2 == 0:
        return "Cannot divide by zero"
    return self.v1 / self.v2

c = calculate(10, 5)

print("Addition:", c.add())
print("Subtraction:", c.sub())
print("Multiplication:", c.mul())
print("Division:", c.div())
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0

# %%
'''4. Write a Python program to create a class that represents a shape.
Include methods to calculate its area and perimeter.
Implement subclasses for different shapes like circle, triangle, and square.'''

import math

class Shape:
    def area(self):
        pass

    def perimeter(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.radius

class Square(Shape):
    def __init__(self, side):
        self.side = side

    def area(self):
        return self.side ** 2

    def perimeter(self):
        return 4 * self.side

class Triangle(Shape):
    def __init__(self, base, height, side1, side2, side3):
        self.base = base
        self.height = height
        self.side1 = side1
        self.side2 = side2
        self.side3 = side3

    def area(self):
        return 0.5 * self.base * self.height

    def perimeter(self):
        return self.side1 + self.side2 + self.side3


c = Circle(5)
s = Square(4)
t = Triangle(3, 6, 3, 4, 5)

print("Circle Area:", c.area())
print("Circle Perimeter:", c.perimeter())

print("Square Area:", s.area())
print("Square Perimeter:", s.perimeter())

print("Triangle Area:", t.area())
print("Triangle Perimeter:", t.perimeter())
# Out:
# Circle Area: 78.53981633974483
# Circle Perimeter: 31.41592653589793
# Square Area: 16
# Square Perimeter: 16
# Triangle Area: 9.0
# Triangle Perimeter: 12

# %%
'''5. Write a Python program to create a class representing a binary search tree. Include methods for inserting and searching for elements in the binary tree.'''

# Node class
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None


# BST class
class BinarySearchTree:
    def __init__(self):
        self.root = None

    # Insert method
    def insert(self, value):
        if self.root is None:
            self.root = Node(value)
        else:
            self._insert(self.root, value)

    def _insert(self, current, value):
        if value < current.value:
            if current.left is None:
                current.left = Node(value)
            else:
                self._insert(current.left, value)
        else:
            if current.right is None:
                current.right = Node(value)
            else:
                self._insert(current.right, value)

    # Search method
    def search(self, value):
        return self._search(self.root, value)

    def _search(self, current, value):
        if current is None:
            return False
        if current.value == value:
            return True
        elif value < current.value:
            return self._search(current.left, value)
        else:
            return self._search(current.right, value)


# Testing
bst = BinarySearchTree()

bst.insert(10)
bst.insert(5)
bst.insert(15)
bst.insert(2)
bst.insert(7)

print("Search 7:", bst.search(7))
print("Search 20:", bst.search(20))
# Out:
# Search 7: True
# Search 20: False

# %%
'''6. Write a Python program to create a class representing a stack data structure. Include methods for pushing and popping elements.'''

class Stack:
    def __init__(self):
        self.stack = []

    # Push method
    def push(self, value):
        self.stack.append(value)

    # Pop method
    def pop(self):
        if len(self.stack) == 0:
            return "Stack is empty"
        return self.stack.pop()


# Testing
s = Stack()

s.push(10)
s.push(20)
s.push(30)

print("Pop:", s.pop())
print("Pop:", s.pop())
print("Stack:", s.stack)
# Out:
# Pop: 30
# Pop: 20
# Stack: [10]

# %%
'''7. Write a Python program to create a class representing a linked list data structure.
   Include methods for displaying linked list data, inserting and deleting nodes.'''

# Node class
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


# Linked List class
class LinkedList:
    def __init__(self):
        self.head = None

    # Insert at end
    def insert(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        temp = self.head
        while temp.next:
            temp = temp.next

        temp.next = new_node

    # Display list
    def display(self):
        temp = self.head
        while temp:
            print(temp.data, end=" -> ")
            temp = temp.next
        print("None")

    # Delete node
    def delete(self, key):
        temp = self.head

        # If head node itself
        if temp and temp.data == key:
            self.head = temp.next
            return

        prev = None
        while temp and temp.data != key:
            prev = temp
            temp = temp.next

        if temp is None:
            print("Value not found")
            return

        prev.next = temp.next


# Testing
ll = LinkedList()

ll.insert(10)
ll.insert(20)
ll.insert(30)

ll.display()

ll.delete(20)

ll.display()
# Out:
# 10 -> 20 -> 30 -> None
# 10 -> 30 -> None

# %%
'''8. Write a Python program to create a class representing a shopping cart. Include methods for adding and removing items, and calculating the total price.'''

class ShoppingCart:
    def __init__(self):
        self.items = {}   # dictionary to store items

    # Add item
    def add_item(self, name, price):
        self.items[name] = price

    # Remove item
    def remove_item(self, name):
        if name in self.items:
            del self.items[name]
        else:
            print("Item not found")

    # Calculate total price
    def total_price(self):
        return sum(self.items.values())

    # Display items
    def display(self):
        print("Cart Items:")
        for name, price in self.items.items():
            print(name, ":", price)


# Testing
cart = ShoppingCart()

cart.add_item("Book", 200)
cart.add_item("Pen", 20)
cart.add_item("Bag", 500)

cart.display()

print("Total:", cart.total_price())

cart.remove_item("Pen")

cart.display()
print("Total after removal:", cart.total_price())
# Out:
# Cart Items:
# Book : 200
# Pen : 20
# Bag : 500
# Total: 720
# Cart Items:
# Book : 200
# Bag : 500
# Total after removal: 700

# %%
'''9. Write a Python program to create a class representing a stack data structure. Include methods for pushing, popping and displaying elements.'''

class stack:
  def __init__(self):
    self.items = []

  def push(self,value):
    return self.items.append(value)

  def pop(self):
    return self.items.pop()

s1 = stack()

s1.push(5)
s1.push(6)
s1.push(7)

print(s1.items)

print(s1.pop())
print(s1.items)
# Out:
# [5, 6, 7]
# 7
# [5, 6]

# %%
'''10. Write a Python program to create a class representing a queue data structure. Include methods for enqueueing and dequeueing elements.'''

class Queue:
    def __init__(self):
        self.items = []

    # Add element
    def enqueue(self, value):
        self.items.append(value)

    # Remove element
    def dequeue(self):
        if len(self.items) == 0:
            return "Queue is empty"
        return self.items.pop(0)


# Testing
q = Queue()

q.enqueue(10)
q.enqueue(20)
q.enqueue(30)

print("Queue:", q.items)

print("Removed:", q.dequeue())
print("Queue after removal:", q.items)
# Out:
# Queue: [10, 20, 30]
# Removed: 10
# Queue after removal: [20, 30]

# %%
'''11. Write a Python program to create a class representing a bank. Include methods for managing customer accounts and transactions.
	Create a Python class called BankAccount which represents a bank account, having as attributes: accountNumber (numeric type),
  name (name of the account owner as string type), balance.
	Create a constructor with parameters: accountNumber, name, balance.
	Create a Deposit() method which manages the deposit actions.
	Create a Withdrawal() method which manages withdrawals actions.
	Create an bankFees() method to apply the bank fees with a percentage of 5% of the balance account.
	Create a display() method to display account details. Give the complete code for the BankAccount class.'''

class bankaccount:
  def __init__(self,accountNumber,name,balance):
    self.accountNumber = accountNumber
    self.name = name
    self.balance =balance

  def deposit(self,amount):
    self.balance += amount

  def withdrawal(self,amount):
    if amount > self.balance:
      return "Insufficient balance"
    self.balance -= amount

  def bankfees(self):
    self.balance -= self.balance * 0.05

  def display(self):
      print("Account Number:", self.accountNumber)
      print("Name:", self.name)
      print("Balance:", self.balance)

acc = bankaccount(12345,'Yash',1000)

acc.deposit(500)
acc.withdrawal(200)
acc.bankfees()

acc.display()
# Out:
# Account Number: 12345
# Name: Yash
# Balance: 1235.0

# %%
'''12. Build a flashcard using class in python. A flashcard is a card having information on both sides, which can be used as an aid in memoization.
    Flashcards usually have a question on one side and an answer on the other.

	Example 1:

	Approach:

	Create a class named FlashCard.
	Initialize dictionary fruits using init() method. Here you have to define fruit name as key and it's color as value. E.g., {"Banana": "yellow", "Strawberries": "pink"}
	Now randomly choose a pair from fruits by using random module and store the key in variable fruit and value in variable color.
	Now prompt the user to answer the color of the randomly chosen fruit.
	If correct print correct else print wrong.
	Output:

	welcome to fruit quiz
	What is the color of Strawberries
	pink
	Correct answer
	Enter 0, if you want to play again: 0
	What is the color of watermelon
	green
	Correct answer
	Enter 0, if you want to play again: 1'''

import random

class FlashCard:
    def __init__(self):
        self.fruits = {
                        "Banana": "yellow",
                        "Strawberries": "pink",
                        "Apple": "red",
                        "Watermelon": "green",
                        "Orange": "orange"
                       }

    def play(self):
        print("Welcome to fruit quiz")

        while True:
            fruit = random.choice(list(self.fruits.keys()))
            correct_answer = self.fruits[fruit]

            user_answer = input(f"What is the color of {fruit}? ")

            if user_answer.lower() == correct_answer:
                print("Correct answer")
            else:
                print("Wrong answer. Correct is:", correct_answer)

            choice = input("Enter 0 to play again, 1 to exit: ")
            if choice != "0":
                break


# Run game
game = FlashCard()
game.play()
# Out:
# Welcome to fruit quiz
# What is the color of Banana? yellow
# Correct answer
# Enter 0 to play again, 1 to exit: 0
# What is the color of Watermelon? green
# Correct answer
# Enter 0 to play again, 1 to exit: 1

# %%
'''13. TechWorld, a technology training center, wants to allocate courses for instructors. An instructor is identified by name,
   technology skills, experience and average feedback. An instructor is allocated a course, if he/she satisfies the below two conditions:

	eligibility criteria:
	if experience is more than 3 years, average feedback should be 4.5 or more
	if experience is 3 years or less, average feedback should be 4 or more
	he/she should posses the technology skill for the course
	Identify the class name and attributes to represent instructors. Write a Python program to implement the class chosen with its attributes and methods.

	Note:

	Consider all instance variables to be private and methods to be public.
	An instructor may have multiple technology skills, so consider instance variable, technology_skill to be a list.
	check_eligibility(): Return true if eligibility criteria is satisfied by the instructor. Else, return false
	allocate_course(technology): Return true if the course which requires the given technology can be allocated to the instructor. Else, return false.
	Represent a few objects of the class, initialize instance variables using setter methods, invoke appropriate methods and test your program.'''

class Instructor:
    def __init__(self):
        self.__name = None
        self.__technology_skill = []
        self.__experience = 0
        self.__average_feedback = 0

    # Setter methods
    def set_name(self, name):
        self.__name = name

    def set_technology_skill(self, skills):
        self.__technology_skill = skills

    def set_experience(self, exp):
        self.__experience = exp

    def set_average_feedback(self, feedback):
        self.__average_feedback = feedback

    # Check eligibility
    def check_eligibility(self):
        if self.__experience > 3:
            if self.__average_feedback >= 4.5:
                return True
        else:
            if self.__average_feedback >= 4:
                return True
        return False

    # Allocate course
    def allocate_course(self, technology):
        if self.check_eligibility() and technology in self.__technology_skill:
            return True
        return False

    # Display
    def display(self):
        print("Name:", self.__name)
        print("Skills:", self.__technology_skill)
        print("Experience:", self.__experience)
        print("Feedback:", self.__average_feedback)


# Testing
ins1 = Instructor()

ins1.set_name("Yash")
ins1.set_technology_skill(["Python", "Java"])
ins1.set_experience(4)
ins1.set_average_feedback(4.6)

ins1.display()

print("Eligible:", ins1.check_eligibility())
print("Can teach Python:", ins1.allocate_course("Python"))
print("Can teach C++:", ins1.allocate_course("C++"))
# Out:
# Name: Yash
# Skills: ['Python', 'Java']
# Experience: 4
# Feedback: 4.6
# Eligible: True
# Can teach Python: True
# Can teach C++: False

# %%
'''14. Write a program that uses datetime module within a class. Enter manufacturing date and expiry date of the product.
   The program must display the years, months and days that are left for expiry.'''


from datetime import date

class Product:
    def __init__(self, mfg_date, exp_date):
        self.mfg_date = mfg_date
        self.exp_date = exp_date

    def time_left(self):
        today = date.today()

        if today > self.exp_date:
            print("Product already expired")
            return

        diff = self.exp_date - today   # gives days

        days = diff.days

        years = days // 365
        months = (days % 365) // 30
        remaining_days = (days % 365) % 30

        print("Time left for expiry:")
        print("Years:", years)
        print("Months:", months)
        print("Days:", remaining_days)


# Example
p = Product(date(2024, 1, 1), date(2026, 12, 31))

p.time_left()
# Out:
# Time left for expiry:
# Years: 0
# Months: 8
# Days: 22

# %%
'''15. A university wants to automate their admission process. Students are admitted based on the marks scored in the qualifying exam.
   A student is identified by student id, age and marks in qualifying exam. Data are valid, if:

	Age is greater than 20
	Marks is between 0 and 100 (both inclusive)
	A student qualifies for admission, if

	Age and marks are valid and
	Marks is 65 or more
	Write a python program to represent the students seeking admission in the university.'''

class student:
  def __init__(self,student_id,age,marks):
    self.student_id = student_id
    self.age = age
    self.marks = marks

  def validate_date(self):
    if self.age > 20 and 0 <= self.marks <= 100:
      return True
    return False

  def check_qualification(self):
    if self.validate_date():
      if self.marks >= 65:
        return True
    return False


s1 = student(101,22,70)
s2 = student(102,19,80)
s3 = student(103,25,60)

print("student 1 Eligible:", s1.check_qualification())
print("student 2 Eligible:", s2.check_qualification())
print("student 3 Eligible:", s3.check_qualification())
# Out:
# student 1 Eligible: True
# student 2 Eligible: False
# student 3 Eligible: False

# %%
'''16. Ice-Cream Scoops and Bowl shop

	Create a class Scoop which has one public property flavor and one private proptery price. Take flavor values during object creation.

	Create a class Bowl with private prperty scoop_list which will have list of scoopd object.

	Create a method add_scoops in Bowl class which will add any no of Scoop objects given as parameter and store it in scoops_list.

	Make getter and setter method for price property.

	Make a method display to display flavour and price of each Scoop in scoop_list and print total price of the bowl by adding all flavour scoops prices.

	Make a method sold in both Scoop class and Bowl class to print no of quantity sold.'''


class Scoop:
    __count = 0   # class variable to count sold scoops

    def __init__(self, flavor):
        self.flavor = flavor
        self.__price = 0
        Scoop.__count += 1

    # Setter
    def set_price(self, price):
        self.__price = price

    # Getter
    def get_price(self):
        return self.__price

    # Sold method
    @classmethod
    def sold(cls):
        print("Total scoops sold:", cls.__count)


class Bowl:
    __bowl_count = 0

    def __init__(self):
        self.__scoop_list = []
        Bowl.__bowl_count += 1

    # Add multiple scoops
    def add_scoops(self, *scoops):
        for scoop in scoops:
            self.__scoop_list.append(scoop)

    # Display scoops and total price
    def display(self):
        total = 0
        print("Scoops in bowl:")

        for scoop in self.__scoop_list:
            print("Flavor:", scoop.flavor, "| Price:", scoop.get_price())
            total += scoop.get_price()

        print("Total Price:", total)

    # Sold method
    @classmethod
    def sold(cls):
        print("Total bowls sold:", cls.__bowl_count)


# Testing
s1 = Scoop("Chocolate")
s1.set_price(50)

s2 = Scoop("Vanilla")
s2.set_price(40)

s3 = Scoop("Strawberry")
s3.set_price(60)

b = Bowl()
b.add_scoops(s1, s2, s3)

b.display()

Scoop.sold()
Bowl.sold()
# Out:
# Scoops in bowl:
# Flavor: Chocolate | Price: 50
# Flavor: Vanilla | Price: 40
# Flavor: Strawberry | Price: 60
# Total Price: 150
# Total scoops sold: 3
# Total bowls sold: 1

# %%
'''17. Create a Bus child class that inherits from the Vehicle class. The default fare charge of any vehicle is seating capacity * 100.
If Vehicle is Bus instance, we need to add an extra 10% on full fare as a maintenance charge.
So total fare for bus instance will become the final amount = total fare + 10% of the total fare.

Note: The bus seating capacity is 50. so the final fare amount should be 5500.
You need to override the fare() method of a Vehicle class in Bus class.'''

class Vehicle:
    def __init__(self, capacity):
        self.capacity = capacity

    def fare(self):
        return self.capacity * 100


class Bus(Vehicle):
    def __init__(self, capacity=50):
        super().__init__(capacity)

    # overriding fare method
    def fare(self):
        base_fare = super().fare()
        maintenance_charge = base_fare * 0.10
        total_fare = base_fare + maintenance_charge
        return total_fare


# Create Bus object
bus = Bus()

# Print final fare
print("Total Bus Fare:", bus.fare())
# Out:
# Total Bus Fare: 5500.0

# %%
'''18. Write a Python class Employee with attributes like emp_id, emp_name, emp_salary, and emp_department and methods like
calculate_emp_salary, emp_assign_department, and print_employee_details.

	Sample Employee Data:
	"ADAMS", "E7876", 50000, "ACCOUNTING"
	"JONES", "E7499", 45000, "RESEARCH"
	"MARTIN", "E7900", 50000, "SALES"
	"SMITH", "E7698", 55000, "OPERATIONS"

	Use 'assign_department' method to change the department of an employee.
	Use 'print_employee_details' method to print the details of an employee.
	Use 'calculate_emp_salary' method takes two arguments: salary and hours_worked, which is the number of hours worked by the employee.
   If the number of hours worked is more than 50, the method computes overtime and adds it to the salary. Overtime is calculated as following formula:
	overtime = hours_worked - 50
	Overtime amount = (overtime * (salary / 50))'''

class Employee:
    def __init__(self, emp_name, emp_id, emp_salary, emp_department):
        self.emp_id = emp_id
        self.emp_name = emp_name
        self.emp_salary = emp_salary
        self.emp_department = emp_department

    # calculate salary with overtime
    def calculate_emp_salary(self, salary, hours_worked):
        if hours_worked > 50:
            overtime = hours_worked - 50
            overtime_amount = overtime * (salary / 50)
            total_salary = salary + overtime_amount
        else:
            total_salary = salary
        return total_salary

    # assign new department
    def emp_assign_department(self, new_dept):
        self.emp_department = new_dept

    # print details
    def print_employee_details(self):
        print("Emp Name:", self.emp_name)
        print("Emp ID:", self.emp_id)
        print("Emp Salary:", self.emp_salary)
        print("Emp Department:", self.emp_department)
        print("-" * 30)


# Create employees
e1 = Employee("ADAMS", "E7876", 50000, "ACCOUNTING")
e2 = Employee("JONES", "E7499", 45000, "RESEARCH")
e3 = Employee("MARTIN", "E7900", 50000, "SALES")
e4 = Employee("SMITH", "E7698", 55000, "OPERATIONS")

# Print details
e1.print_employee_details()
e2.print_employee_details()
e3.print_employee_details()
e4.print_employee_details()

# Change department
e1.emp_assign_department("HR")

print("After changing department of ADAMS:")
e1.print_employee_details()

# Calculate salary with overtime
print("Salary with overtime:")
print("ADAMS:", e1.calculate_emp_salary(50000, 55))
print("JONES:", e2.calculate_emp_salary(45000, 48))
# Out:
# Emp Name: ADAMS
# Emp ID: E7876
# Emp Salary: 50000
# Emp Department: ACCOUNTING
# ------------------------------
# Emp Name: JONES
# Emp ID: E7499
# Emp Salary: 45000
# Emp Department: RESEARCH
# ------------------------------
# Emp Name: MARTIN
# Emp ID: E7900
# Emp Salary: 50000
# Emp Department: SALES
# ------------------------------
# Emp Name: SMITH
# Emp ID: E7698
# Emp Salary: 55000
# Emp Department: OPERATIONS
# ------------------------------
# After changing department of ADAMS:
# Emp Name: ADAMS
# Emp ID: E7876
# Emp Salary: 50000
# Emp Department: HR
# ------------------------------
# Salary with overtime:
# ADAMS: 55000.0
# JONES: 45000

# %%
'''19. Write a Python class Restaurant with attributes like menu_items, book_table, and customer_orders,
 and methods like add_item_to_menu, book_tables, and customer_order.

	Perform the following tasks now:

	Now add items to the menu.
	Make table reservations.
	Take customer orders.
	Print the menu.
	Print table reservations.
	Print customer orders.
	Note: Use dictionaries and lists to store the data.'''

class Restaurant:
    def __init__(self):
        self.menu_items = {}
        self.book_table = []
        self.customer_orders = []

    # add item to menu
    def add_item_to_menu(self, item, price):
        self.menu_items[item] = price

    # book table
    def book_tables(self, table_no):
        self.book_table.append(table_no)

    # take customer order
    def customer_order(self, table_no, items):
        order = {"table": table_no, "items": items}
        self.customer_orders.append(order)

    # print menu
    def print_menu(self):
        print("Menu:")
        for item, price in self.menu_items.items():
            print(item, ":", price)
        print("-" * 30)

    # print table reservations
    def print_table_reservations(self):
        print("Table Reservations:", self.book_table)
        print("-" * 30)

    # print customer orders
    def print_customer_orders(self):
        print("Customer Orders:")
        for order in self.customer_orders:
            print("Table", order["table"], "ordered", order["items"])
        print("-" * 30)


# Create object
r = Restaurant()

# Add menu items
r.add_item_to_menu("Pizza", 250)
r.add_item_to_menu("Burger", 150)
r.add_item_to_menu("Pasta", 200)

# Book tables
r.book_tables(1)
r.book_tables(2)

# Take orders
r.customer_order(1, ["Pizza", "Burger"])
r.customer_order(2, ["Pasta"])

# Print all details
r.print_menu()
r.print_table_reservations()
r.print_customer_orders()
# Out:
# Menu:
# Pizza : 250
# Burger : 150
# Pasta : 200
# ------------------------------
# Table Reservations: [1, 2]
# ------------------------------
# Customer Orders:
# Table 1 ordered ['Pizza', 'Burger']
# Table 2 ordered ['Pasta']
# ------------------------------

# %%
'''20. Write a Python class BankAccount with attributes like account_number, balance, date_of_opening
       and customer_name, and methods like deposit, withdraw, and check_balance.'''

class BankAccount:
    def __init__(self, account_number, balance, date_of_opening, customer_name):
        self.account_number = account_number
        self.balance = balance
        self.date_of_opening = date_of_opening
        self.customer_name = customer_name

    # deposit money
    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print("Deposited:", amount)
        else:
            print("Invalid amount!")

    # withdraw money
    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient balance!")
        elif amount <= 0:
            print("Invalid amount!")
        else:
            self.balance -= amount
            print("Withdrawn:", amount)

    # check balance
    def check_balance(self):
        print("Current Balance:", self.balance)


# Create account
acc = BankAccount(101, 5000, "14-04-2026", "Yash")

# Operations
acc.check_balance()
acc.deposit(2000)
acc.withdraw(3000)
acc.check_balance()
# Out:
# Current Balance: 5000
# Deposited: 2000
# Withdrawn: 3000
# Current Balance: 4000

# %%
'''21. Write a Python class Inventory with attributes like item_id, item_name, stock_count, and price, and
       methods like add_item, update_item, and check_item_details.'''

class Inventory:
    def __init__(self):
        self.items = {}   # dictionary to store inventory

    # add new item
    def add_item(self, item_id, item_name, stock_count, price):
        self.items[item_id] = {
            "name": item_name,
            "stock": stock_count,
            "price": price
        }

    # update item details
    def update_item(self, item_id, stock_count=None, price=None):
        if item_id in self.items:
            if stock_count is not None:
                self.items[item_id]["stock"] = stock_count
            if price is not None:
                self.items[item_id]["price"] = price
        else:
            print("Item not found!")

    # check item details
    def check_item_details(self, item_id):
        if item_id in self.items:
            item = self.items[item_id]
            print("Item ID:", item_id)
            print("Name:", item["name"])
            print("Stock:", item["stock"])
            print("Price:", item["price"])
        else:
            print("Item not found!")


# Create object
inv = Inventory()

# Add items
inv.add_item(101, "Laptop", 10, 50000)
inv.add_item(102, "Mouse", 50, 500)

# Check details
inv.check_item_details(101)

# Update item
inv.update_item(101, stock_count=8, price=48000)

print("\nAfter Update:")
inv.check_item_details(101)
# Out:
# Item ID: 101
# Name: Laptop
# Stock: 10
# Price: 50000
#
# After Update:
# Item ID: 101
# Name: Laptop
# Stock: 8
# Price: 48000
